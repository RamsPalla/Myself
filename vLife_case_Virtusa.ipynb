# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_excel('vLife_case_Virtusa.xls')
df
# Out:
#           ID  Score Feature_1  Feature_2  Feature_3  Feature_4  Feature_5  \
# 0          1    918         A         36     3000.0       14.4  UnSecured
# 1          3    903         A        120    21000.0        7.9  secured
# 2          4   1060         X         78     7200.0        7.9  secured
# 3          6    839         B         60     8000.0       16.9  UnSecured
# 4          7   1057         X         60     7650.0        7.4  UnSecured
# ...      ...    ...       ...        ...        ...        ...        ...
# 16378  42067    952         X         60     5000.0        8.9  UnSecured
# 16379  42068    922         A         60     7500.0        7.9  UnSecured
# 16380  42069    831         C         60     1000.0       25.9  UnSecured
# 16381  42070    790         D         36     3000.0       25.9  UnSecured
# 16382  42072    905         A         60     8460.0        7.9  UnSecured
#
#        Feature_6  Class  Feature_7  ... Feature_32 Feature_33  Feature_34  \
# ...

# %%
df.shape
# Out:
# (16383, 52)

# %%
df.info
# Out:
# <bound method DataFrame.info of           ID  Score Feature_1  Feature_2  Feature_3  Feature_4  Feature_5  \
# 0          1    918         A         36     3000.0       14.4  UnSecured
# 1          3    903         A        120    21000.0        7.9  secured
# 2          4   1060         X         78     7200.0        7.9  secured
# 3          6    839         B         60     8000.0       16.9  UnSecured
# 4          7   1057         X         60     7650.0        7.4  UnSecured
# ...      ...    ...       ...        ...        ...        ...        ...
# 16378  42067    952         X         60     5000.0        8.9  UnSecured
# 16379  42068    922         A         60     7500.0        7.9  UnSecured
# 16380  42069    831         C         60     1000.0       25.9  UnSecured
# 16381  42070    790         D         36     3000.0       25.9  UnSecured
# 16382  42072    905         A         60     8460.0        7.9  UnSecured
#
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Score', 'Feature_1', 'Feature_2', 'Feature_3', 'Feature_4',
#        'Feature_5', 'Feature_6', 'Class', 'Feature_7', 'Staus', 'Indicator',
#        'Feature_8', 'Feature_9', 'Gender', 'Employement', 'Feature_10',
#        'Feature_11', 'Feature_12', 'Range', 'Feature_14', 'Feature_15',
#        'Feature_16', 'Feature_17', 'Feature_18', 'Feature_19', 'Feature_20',
#        'Time', 'Value', 'Balance', 'Feature_21', 'Feature_22', 'Feature_23',
#        'Feature_24', 'Age', 'Feature_25', 'Feature_26', 'Feature_27',
#        'Feature_28', 'Feature_29', 'Feature_30', 'Feature_31', 'Feature_32',
#        'Feature_33', 'Feature_34', 'Feature_35', 'Feature_36', 'Feature_37',
#        'Feature_38', 'Feature_39', 'Feature_40', 'Target'],
#       dtype='object')

# %% [markdown]
# ### Data Pre-processing: Finding out Nan Values

# %%
df.isna()
# Out:
#           ID  Score  Feature_1  Feature_2  Feature_3  Feature_4  Feature_5  \
# 0      False  False      False      False      False      False      False
# 1      False  False      False      False      False      False      False
# 2      False  False      False      False      False      False      False
# 3      False  False      False      False      False      False      False
# 4      False  False      False      False      False      False      False
# ...      ...    ...        ...        ...        ...        ...        ...
# 16378  False  False      False      False      False      False      False
# 16379  False  False      False      False      False      False      False
# 16380  False  False      False      False      False      False      False
# 16381  False  False      False      False      False      False      False
# 16382  False  False      False      False      False      False      False
#
# ...

# %%
df.isna().any()
# Out:
# ID             False
# Score          False
# Feature_1      False
# Feature_2      False
# Feature_3      False
# Feature_4      False
# Feature_5      False
# Feature_6      False
# Class          False
# Feature_7      False
# Staus          False
# Indicator      False
# Feature_8      False
# Feature_9      False
# Gender         False
# Employement    False
# Feature_10     False
# Feature_11     False
# Feature_12     False
# Range          False
# Feature_14     False
# Feature_15     False
# Feature_16     False
# Feature_17     False
# Feature_18     False
# Feature_19     False
# Feature_20     False
# Time           False
# Value          False
# Balance        False
# Feature_21     False
# Feature_22     False
# Feature_23     False
# Feature_24     False
# Age            False
# Feature_25     False
# Feature_26     False
# Feature_27     False
# Feature_28     False
# Feature_29     False
# Feature_30     False
# Feature_31     False
# Feature_32     False
# ...

# %% [markdown]
# ### Statistica Description of Dataset

# %%
df.describe()
# Out:
#                  ID         Score     Feature_2     Feature_3     Feature_4  \
# count  16383.000000  16383.000000  16383.000000  16383.000000  16383.000000
# mean   21168.695294    882.061832     59.142892   7364.007758     18.754587
# std    12142.797527     93.149605     26.689123   6673.343595      9.662504
# min        1.000000    352.000000      6.000000    500.000000      0.000000
# 25%    10699.000000    818.000000     48.000000   3000.000000      9.900000
# 50%    21303.000000    882.000000     60.000000   5300.000000     16.900000
# 75%    31689.000000    947.000000     60.000000   9000.000000     24.900000
# max    42072.000000   1295.000000    300.000000  75000.000000     50.400000
#
#           Feature_6         Class     Feature_7     Feature_8   Employement  \
# count  16383.000000  16383.000000  16383.000000  16383.000000  16383.000000
# mean      29.419703      5.352683    120.488128      0.808460    103.096075
# ...

# %% [markdown]
# ### Score - Highest to lowest

# %%
df['Score'].value_counts()
# Out:
# 896     147
# 953     145
# 1006    137
# 859     133
# 893     130
#        ...
# 352       1
# 593       1
# 1264      1
# 1257      1
# 562       1
# Name: Score, Length: 613, dtype: int64

# %% [markdown]
# # Data Visulization in Python

# %% [markdown]
# ### importing the libraries

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %% [markdown]
# ## Line Plot

# %%
df.head()
# Out:
#    ID  Score Feature_1  Feature_2  Feature_3  Feature_4  Feature_5  Feature_6  \
# 0   1    918         A         36     3000.0       14.4  UnSecured         46
# 1   3    903         A        120    21000.0        7.9  secured           16
# 2   4   1060         X         78     7200.0        7.9  secured           17
# 3   6    839         B         60     8000.0       16.9  UnSecured         47
# 4   7   1057         X         60     7650.0        7.4  UnSecured         55
#
#    Class  Feature_7  ... Feature_32 Feature_33  Feature_34 Feature_35  \
# 0      8        132  ...          0          9          10          N
# 1      3        288  ...          0          6          22          N
# 2      3        276  ...          0          1          21          N
# 3      8         48  ...          0          5           0          N
# 4     10        156  ...          0          1          13          N
#
#   Feature_36  Feature_37 Feature_38 Feature_39 Feature_40    Target
# ...

# %% [markdown]
# ### lineplot with score ans class column data

# %%
sns.lineplot(x = 'Score', y = 'Class', data = df)
plt.show()

# %% [markdown]
# ### mapping another column with a different color

# %%
sns.lineplot(x = 'Score', y = 'Class', data = df, hue = 'Feature_5')
plt.show()

# %% [markdown]
# ### adding some styling for the Feature_5 column data

# %%
sns.lineplot(x = 'Score', y = 'Class', data = df, hue = 'Feature_5', style = 'Feature_5')
plt.show()

# %% [markdown]
# ### Adding markers for value point

# %%
sns.lineplot(x = 'Score', y = 'Class', data = df, hue = 'Feature_5', style = 'Feature_5', markers = True)
plt.show()

# %% [markdown]
# ## Barplot

# %%
df.head()
# Out:
#    ID  Score Feature_1  Feature_2  Feature_3  Feature_4  Feature_5  Feature_6  \
# 0   1    918         A         36     3000.0       14.4  UnSecured         46
# 1   3    903         A        120    21000.0        7.9  secured           16
# 2   4   1060         X         78     7200.0        7.9  secured           17
# 3   6    839         B         60     8000.0       16.9  UnSecured         47
# 4   7   1057         X         60     7650.0        7.4  UnSecured         55
#
#    Class  Feature_7  ... Feature_32 Feature_33  Feature_34 Feature_35  \
# 0      8        132  ...          0          9          10          N
# 1      3        288  ...          0          6          22          N
# 2      3        276  ...          0          1          21          N
# 3      8         48  ...          0          5           0          N
# 4     10        156  ...          0          1          13          N
#
#   Feature_36  Feature_37 Feature_38 Feature_39 Feature_40    Target
# ...

# %% [markdown]
# ### checking Feature_38

# %%
sns.barplot(x='Target', y='Feature_38', data = df)
plt.show()

# %% [markdown]
# ### checking Feature_7

# %%
sns.barplot(x='Target', y='Feature_7', data = df)
plt.show()

# %% [markdown]
# ### adding a hue to show Feature_38

# %%
sns.barplot(x='Target', y='Feature_7', data = df, hue = 'Feature_38')
plt.show()

# %% [markdown]
# ### Using palettes to assign different color elements

# %%
sns.barplot(x='Target', y='Feature_7', data = df, palette = 'vlag')
plt.show()

# %%
sns.barplot(x='Target', y='Feature_7', data = df, color = 'red')
plt.show()

# %% [markdown]
# # Scatter Plot

# %%
df.head()
# Out:
#    ID  Score Feature_1  Feature_2  Feature_3  Feature_4  Feature_5  Feature_6  \
# 0   1    918         A         36     3000.0       14.4  UnSecured         46
# 1   3    903         A        120    21000.0        7.9  secured           16
# 2   4   1060         X         78     7200.0        7.9  secured           17
# 3   6    839         B         60     8000.0       16.9  UnSecured         47
# 4   7   1057         X         60     7650.0        7.4  UnSecured         55
#
#    Class  Feature_7  ... Feature_32 Feature_33  Feature_34 Feature_35  \
# 0      8        132  ...          0          9          10          N
# 1      3        288  ...          0          6          22          N
# 2      3        276  ...          0          1          21          N
# 3      8         48  ...          0          5           0          N
# 4     10        156  ...          0          1          13          N
#
#   Feature_36  Feature_37 Feature_38 Feature_39 Feature_40    Target
# ...

# %% [markdown]
# ### plotting Target and Feature_7

# %%
sns.scatterplot(x='Target', y = 'Feature_7', data = df)
plt.show()

# %% [markdown]
# ### adding hue on Feature_39 to discern better

# %%
sns.scatterplot(x='Target', y = 'Feature_7', data = df, hue = 'Feature_39')
plt.show()

# %% [markdown]
# ### Adding hue on Feature_38 to help differentiate

# %%
sns.scatterplot(x='Target', y = 'Feature_7', data = df, hue = 'Feature_38')
plt.show()

# %% [markdown]
# # Histogram/Distplot

# %%
df.head()
# Out:
#    ID  Score Feature_1  Feature_2  Feature_3  Feature_4  Feature_5  Feature_6  \
# 0   1    918         A         36     3000.0       14.4  UnSecured         46
# 1   3    903         A        120    21000.0        7.9  secured           16
# 2   4   1060         X         78     7200.0        7.9  secured           17
# 3   6    839         B         60     8000.0       16.9  UnSecured         47
# 4   7   1057         X         60     7650.0        7.4  UnSecured         55
#
#    Class  Feature_7  ... Feature_32 Feature_33  Feature_34 Feature_35  \
# 0      8        132  ...          0          9          10          N
# 1      3        288  ...          0          6          22          N
# 2      3        276  ...          0          1          21          N
# 3      8         48  ...          0          5           0          N
# 4     10        156  ...          0          1          13          N
#
#   Feature_36  Feature_37 Feature_38 Feature_39 Feature_40    Target
# ...

# %% [markdown]
# ### plotting the histogram based on the Score

# %%
sns.distplot(df['Score'])
plt.show()
# Out:
# C:\Users\Rambabu\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### printing only the frequency curve

# %%
sns.distplot(df['Score'],hist = False)
plt.show()
# Out:
# C:\Users\Rambabu\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### adding some color to the distribution plot

# %%
sns.distplot(df['Score'], color = 'green')
plt.show()
# Out:
# C:\Users\Rambabu\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['Score'], color = 'red')
plt.show()
# Out:
# C:\Users\Rambabu\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### plotting only the histogram without the frequency curve

# %%
sns.distplot(df['Score'], kde = False, color = 'green')
plt.show()
# Out:
# C:\Users\Rambabu\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### changing the number of bins

# %%
sns.distplot(df['Score'], kde = False, color = 'green',bins=5)
plt.show()

# %% [markdown]
# ### plotting on the vertical axis

# %%
sns.distplot(df['Score'], kde = False, color = 'green',bins=5,vertical = True)
plt.show()

# %% [markdown]
# # Boxplot

# %%
df.head()
# Out:
#    ID  Score Feature_1  Feature_2  Feature_3  Feature_4  Feature_5  Feature_6  \
# 0   1    918         A         36     3000.0       14.4  UnSecured         46
# 1   3    903         A        120    21000.0        7.9  secured           16
# 2   4   1060         X         78     7200.0        7.9  secured           17
# 3   6    839         B         60     8000.0       16.9  UnSecured         47
# 4   7   1057         X         60     7650.0        7.4  UnSecured         55
#
#    Class  Feature_7  ... Feature_32 Feature_33  Feature_34 Feature_35  \
# 0      8        132  ...          0          9          10          N
# 1      3        288  ...          0          6          22          N
# 2      3        276  ...          0          1          21          N
# 3      8         48  ...          0          5           0          N
# 4     10        156  ...          0          1          13          N
#
#   Feature_36  Feature_37 Feature_38 Feature_39 Feature_40    Target
# ...

# %% [markdown]
# ### plotting based on Target and Score columns

# %%
sns.boxplot(x='Target', y='Score', data = df)
plt.show()

# %% [markdown]
# ### changing line width of boxplot

# %%
sns.boxplot(x='Target', y='Score', data = df, palette = 'Set1',linewidth=5)
plt.show()

# %% [markdown]
# ### plotting based on custom on x axis

# %%
sns.boxplot(x='Target', y='Feature_2', data = df, palette = 'Set1',linewidth=5,order=['Critical', 'Joint', 'Single'], hue='Feature_5')
plt.show()

# %%
# Importing basic packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pandas_profiling import ProfileReport
from subprocess import check_output
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn import metrics
# %matplotlib inline
from sklearn.metrics import classification_report, accuracy_score

# %%
df.head()
# Out:
#    ID  Score Feature_1  Feature_2  Feature_3  Feature_4  Feature_5  Feature_6  \
# 0   1    918         A         36     3000.0       14.4  UnSecured         46
# 1   3    903         A        120    21000.0        7.9  secured           16
# 2   4   1060         X         78     7200.0        7.9  secured           17
# 3   6    839         B         60     8000.0       16.9  UnSecured         47
# 4   7   1057         X         60     7650.0        7.4  UnSecured         55
#
#    Class  Feature_7  ... Feature_32 Feature_33  Feature_34 Feature_35  \
# 0      8        132  ...          0          9          10          N
# 1      3        288  ...          0          6          22          N
# 2      3        276  ...          0          1          21          N
# 3      8         48  ...          0          5           0          N
# 4     10        156  ...          0          1          13          N
#
#   Feature_36  Feature_37 Feature_38 Feature_39 Feature_40    Target
# ...

# %% [markdown]
# ### Details about the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16383 entries, 0 to 16382
# Data columns (total 52 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           16383 non-null  int64
#  1   Score        16383 non-null  int64
#  2   Feature_1    16383 non-null  object
#  3   Feature_2    16383 non-null  int64
#  4   Feature_3    16383 non-null  float64
#  5   Feature_4    16383 non-null  float64
#  6   Feature_5    16383 non-null  object
#  7   Feature_6    16383 non-null  int64
#  8   Class        16383 non-null  int64
#  9   Feature_7    16383 non-null  int64
#  10  Staus        16383 non-null  object
#  11  Indicator    16383 non-null  object
#  12  Feature_8    16383 non-null  int64
#  13  Feature_9    16383 non-null  object
#  14  Gender       16383 non-null  object
#  15  Employement  16383 non-null  int64
#  16  Feature_10   16383 non-null  object
#  17  Feature_11   16383 non-null  object
# ...

# %% [markdown]
# ### statistical aspect of the dataset

# %%
df.describe()
# Out:
#                  ID         Score     Feature_2     Feature_3     Feature_4  \
# count  16383.000000  16383.000000  16383.000000  16383.000000  16383.000000
# mean   21168.695294    882.061832     59.142892   7364.007758     18.754587
# std    12142.797527     93.149605     26.689123   6673.343595      9.662504
# min        1.000000    352.000000      6.000000    500.000000      0.000000
# 25%    10699.000000    818.000000     48.000000   3000.000000      9.900000
# 50%    21303.000000    882.000000     60.000000   5300.000000     16.900000
# 75%    31689.000000    947.000000     60.000000   9000.000000     24.900000
# max    42072.000000   1295.000000    300.000000  75000.000000     50.400000
#
#           Feature_6         Class     Feature_7     Feature_8   Employement  \
# count  16383.000000  16383.000000  16383.000000  16383.000000  16383.000000
# mean      29.419703      5.352683    120.488128      0.808460    103.096075
# ...

# %% [markdown]
# ### Preprocessing  - Checking for NaN values

# %%
df.isna().any()
# Out:
# ID             False
# Score          False
# Feature_1      False
# Feature_2      False
# Feature_3      False
# Feature_4      False
# Feature_5      False
# Feature_6      False
# Class          False
# Feature_7      False
# Staus          False
# Indicator      False
# Feature_8      False
# Feature_9      False
# Gender         False
# Employement    False
# Feature_10     False
# Feature_11     False
# Feature_12     False
# Range          False
# Feature_14     False
# Feature_15     False
# Feature_16     False
# Feature_17     False
# Feature_18     False
# Feature_19     False
# Feature_20     False
# Time           False
# Value          False
# Balance        False
# Feature_21     False
# Feature_22     False
# Feature_23     False
# Feature_24     False
# Age            False
# Feature_25     False
# Feature_26     False
# Feature_27     False
# Feature_28     False
# Feature_29     False
# Feature_30     False
# Feature_31     False
# Feature_32     False
# ...

# %% [markdown]
# ### Count of Nan Values

# %%
df.isnull().sum()
# Out:
# ID                0
# Score             0
# Feature_1         0
# Feature_2         0
# Feature_3         0
# Feature_4         0
# Feature_5         0
# Feature_6         0
# Class             0
# Feature_7         0
# Staus             0
# Indicator         0
# Feature_8         0
# Feature_9         0
# Gender            0
# Employement       0
# Feature_10        0
# Feature_11        0
# Feature_12        0
# Range             0
# Feature_14        0
# Feature_15        0
# Feature_16        0
# Feature_17        0
# Feature_18        0
# Feature_19        0
# Feature_20        0
# Time              0
# Value             0
# Balance           0
# Feature_21        0
# Feature_22        0
# Feature_23        0
# Feature_24        0
# Age               0
# Feature_25        0
# Feature_26        0
# Feature_27        0
# Feature_28        0
# Feature_29        0
# Feature_30        0
# Feature_31        0
# Feature_32        0
# Feature_33        0
# Feature_34        0
# ...

# %% [markdown]
# ### Understanding correlation between the labels

# %%
# Correlation
correlation_metrics = df.corr()
fig = plt.figure(figsize=(14,9))
sns.heatmap(correlation_metrics, vmax = .9, square=True) #annot = value
plt.show()
print(correlation_metrics)
# Out:
#                    ID     Score  Feature_2  Feature_3  Feature_4  Feature_6  \
# ID           1.000000 -0.002424  -0.045179  -0.033426   0.012500   0.000258
# Score       -0.002424  1.000000   0.027229   0.200176  -0.675112  -0.083799
# Feature_2   -0.045179  0.027229   1.000000   0.721736  -0.389823   0.041727
# Feature_3   -0.033426  0.200176   0.721736   1.000000  -0.508391  -0.047204
# Feature_4    0.012500 -0.675112  -0.389823  -0.508391   1.000000   0.050530
# Feature_6    0.000258 -0.083799   0.041727  -0.047204   0.050530   1.000000
# Class        0.006713 -0.039007   0.013228  -0.030183   0.024880   0.695923
# Feature_7    0.016713  0.270914  -0.004591   0.022056  -0.151103   0.116184
# Feature_8    0.032648 -0.059306   0.034455   0.009700   0.020299  -0.017150
# Employement -0.005489  0.294277   0.037290   0.097757  -0.237106   0.001578
# Range        0.009417  0.047819   0.191210   0.238649  -0.259213  -0.028263
# ...

# %% [markdown]
# ### Setting up Environment

# %%
import random
import pandas as pd
import numpy as np

from sklearn.model_selection import KFold
from sklearn.model_selection import GroupKFold
from sklearn.model_selection import GridSearchCV

from sklearn.linear_model import SGDClassifier
from sklearn.svm import SVC
import xgboost as xgb
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import confusion_matrix
from sklearn.metrics import balanced_accuracy_score
from sklearn.model_selection import learning_curve
from sklearn.model_selection import ShuffleSplit
from sklearn.feature_selection import SelectFromModel

import matplotlib.pyplot as plt
import seaborn as sb
import time

# %% [markdown]
# ### function for preparing our training and testing data

# %%
df.head()
# Out:
#    ID  Score Feature_1  Feature_2  Feature_3  Feature_4  Feature_5  Feature_6  \
# 0   1    918         A         36     3000.0       14.4  UnSecured         46
# 1   3    903         A        120    21000.0        7.9  secured           16
# 2   4   1060         X         78     7200.0        7.9  secured           17
# 3   6    839         B         60     8000.0       16.9  UnSecured         47
# 4   7   1057         X         60     7650.0        7.4  UnSecured         55
#
#    Class  Feature_7  ... Feature_32 Feature_33  Feature_34 Feature_35  \
# 0      8        132  ...          0          9          10          N
# 1      3        288  ...          0          6          22          N
# 2      3        276  ...          0          1          21          N
# 3      8         48  ...          0          5           0          N
# 4     10        156  ...          0          1          13          N
#
#   Feature_36  Feature_37 Feature_38 Feature_39 Feature_40    Target
# ...

# %% [markdown]
# ### Deleting missing(NaN) values in Target column

# %%
df = df.dropna()
df.head()
# Out:
#    ID  Score Feature_1  Feature_2  Feature_3  Feature_4  Feature_5  Feature_6  \
# 1   3    903         A        120    21000.0        7.9  secured           16
# 2   4   1060         X         78     7200.0        7.9  secured           17
# 3   6    839         B         60     8000.0       16.9  UnSecured         47
# 4   7   1057         X         60     7650.0        7.4  UnSecured         55
# 5   8    913         A        120    33000.0        9.4  secured           59
#
#    Class  Feature_7  ... Feature_32 Feature_33  Feature_34 Feature_35  \
# 1      3        288  ...          0          6          22          N
# 2      3        276  ...          0          1          21          N
# 3      8         48  ...          0          5           0          N
# 4     10        156  ...          0          1          13          N
# 5     11         18  ...          0          1           1          N
#
#   Feature_36  Feature_37 Feature_38 Feature_39 Feature_40    Target
# ...

# %%
from sklearn.preprocessing import OneHotEncoder

# select the categorical columns to be encoded
categorical_cols = ['Feature_1', 'Feature_5', 'Staus', 'Indicator', 'Feature_9', 'Gender', 'Feature_10', 'Feature_11', 'Feature_12', 'Feature_14', 'Feature_15', 'Feature_16', 'Feature_17', 'Feature_18', 'Feature_19', 'Feature_20', 'Feature_24', 'Feature_35', 'Feature_40']

# create an instance of the OneHotEncoder class
encoder = OneHotEncoder(handle_unknown='ignore')

# fit the encoder to the categorical columns in the training data
encoder.fit(X_train[categorical_cols])

# transform the categorical columns in the training and test data
X_train_encoded = encoder.transform(X_train[categorical_cols])
X_test_encoded = encoder.transform(X_test[categorical_cols])

# drop the original categorical columns from the training and test data
X_train = X_train.drop(categorical_cols, axis=1)
X_test = X_test.drop(categorical_cols, axis=1)

# concatenate the encoded categorical columns with the numerical columns
import scipy.sparse as sp

X_train = sp.hstack([X_train.values, X_train_encoded])
X_test = sp.hstack([X_test.values, X_test_encoded])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17412/1829013734.py in <module>
#       8
#       9 # fit the encoder to the categorical columns in the training data
# ---> 10 encoder.fit(X_train[categorical_cols])
#      11
#      12 # transform the categorical columns in the training and test data
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# ...

# %%
Model = RandomForestClassifier()
X=df.drop("Target",axis=1)
y=df['Target']
from sklearn.model_selection import train_test_split,GridSearchCV
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.33,random_state=10)
Model.fit(X_train,y_train)

# %%
# select the categorical columns to be encoded
categorical_cols = ['Feature_1', 'Feature_5', 'Staus', 'Indicator', 'Feature_9', 'Gender', 'Feature_10', 'Feature_11', 'Feature_12', 'Feature_14', 'Feature_15', 'Feature_16', 'Feature_17', 'Feature_18', 'Feature_19', 'Feature_20', 'Feature_24', 'Feature_35', ]

# create an instance of the OneHotEncoder class
encoder = OneHotEncoder(handle_unknown='ignore')

# fit the encoder to the categorical columns in the training data
encoder.fit(X_train[categorical_cols])

# transform the categorical columns in the training and test data
X_train_encoded = encoder.transform(X_train[categorical_cols])
X_test_encoded = encoder.transform(X_test[categorical_cols])

# drop the original categorical columns from the training and test data
X_train = X_train.drop(categorical_cols, axis=1)
X_test = X_test.drop(categorical_cols, axis=1)

# concatenate the encoded categorical columns with the numerical columns
import scipy.sparse as sp

X_train = sp.hstack([X_train.values, X_train_encoded])
X_test = sp.hstack([X_test.values, X_test_encoded])
